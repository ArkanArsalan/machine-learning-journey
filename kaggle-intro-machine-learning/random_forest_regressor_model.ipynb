# %% [markdown]
# # Machine Learning Model Using Random Forest Regression

# %% [markdown]
# ## Prepare the data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

dataset_path = "./dataset/melb_data.csv"
dataset = pd.read_csv(dataset_path)

feature_name = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

x = dataset[feature_name]
y = dataset["Price"]

train_x, test_x, train_y, test_y = train_test_split(x, y, random_state=1)

# %% [markdown]
# ## Build the Model

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(random_state=1)

rf_model.fit(train_x, train_y)
# Out:
# RandomForestRegressor(random_state=1)

# %% [markdown]
# ## Prediction

# %%
predictions = rf_model.predict(test_x)

print(f"Predictions price: {predictions}")
print(f"Actual price: {test_y.tolist()}")
# Out:
# Predictions price: [1876160.  819910. 2433025. ... 1307080. 1303615.  533375.]
# ...

# %% [markdown]
# ## Validate Model

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(test_y, predictions)
# Out:
# 180544.06532524488
